# %% [markdown]
# <a href="https://colab.research.google.com/github/saitharun5515/Statistical-Analysis-on-Churn-Data/blob/main/Alzheimers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nbformat

nb = nbformat.read("/content/your_notebook.ipynb", as_version=4)

# remove notebook-level widgets
nb.metadata.pop("widgets", None)

# remove cell-level widgets
for cell in nb.cells:
    if "widgets" in cell.get("metadata", {}):
        cell.metadata.pop("widgets", None)

nbformat.write(nb, "/content/clean.ipynb")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/nbformat/__init__.py in read(fp, as_version, capture_validation_error, **kwargs)
#     168     try:
# --> 169         buf = fp.read()
#     170     except AttributeError:
#
# AttributeError: 'str' object has no attribute 'read'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-602488135.py in <cell line: 0>()
#       1 import nbformat
#       2
# ----> 3 nb = nbformat.read("/content/your_notebook.ipynb", as_version=4)
#       4
#       5 # remove notebook-level widgets
#
# /usr/local/lib/python3.12/dist-packages/nbformat/__init__.py in read(fp, as_version, capture_validation_error, **kwargs)
#     169         buf = fp.read()
#     170     except AttributeError:
# ...
